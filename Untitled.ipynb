# %%
song_df.limit(5).toPandas()
# Out:
#               song_id                                              title  \
# 0  SOAOIBZ12AB01815BE  I Hold Your Hand In Mine [Live At Royal Albert...
# 1  SONYPOM12A8C13B2D7  I Think My Wife Is Running Around On Me (Taco ...
# 2  SODREIN12A58A7F2E5      A Whiter Shade Of Pale (Live @ Fillmore West)
# 3  SOYMRWW12A6D4FAB14        The Moon And I (Ordinary Day Album Version)
# 4  SOWQTQZ12A58A7B63E           Streets On Fire (Explicit Album Version)
#
#     duration  year           artist_id
# 0   43.36281  2000  ARPBNLO1187FB3D52F
# 1  186.48771  2005  ARDNS031187B9924F0
# 2  326.00771     0  ARLTWXK1187FB5A3F8
# 3  267.70240     0  ARKFYS91187B98E58F
# 4  279.97995     0  ARPFHN61187FB575F6

# %%
# df = songplays
# songplays.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: double (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- artist_id: string (nullable = true)

# %%
# df = spark.read.json('s3a://udacity-marco/log-data/*.json')

# %%
# from pyspark.sql.functions import from_unixtime
# time_df.select(from_unixtime('ts').alias('ts')).collect()

# %%
# df = df.withColumn("ts",df.ts.cast('string'))
# get_datetime = udf(lambda x: datetime.fromtimestamp(x))
# df = df.withColumn('date', get_datetime(df.ts))
# df.show(5)

# %%
# log_data = '{}/data/log-data'.format(os.getcwd())
# df = spark.read.json(log_data)
from pyspark.sql.types import TimestampType, DateType
get_timestamp = udf(
    lambda x: datetime.fromtimestamp(x / 1000), TimestampType()
)
df = df.withColumn('timestamp', get_timestamp(col('ts')))
# create datetime column from original timestamp column
get_timestamp = udf(
    lambda x: datetime.fromtimestamp(x / 1000), DateType()
)
df = df.withColumn('start_time', get_timestamp(col('ts')))
df.limit(5).toPandas()
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0              Elena  Logged In      Lily      F              5     Koch
# 1          Percubaba  Logged In    Sylvie      F              4     Cruz
# 2  Calvin Richardson  Logged In     Layla      F             98  Griffin
# 3        Samy Deluxe  Logged In     Tegan      F             43   Levine
#
#       length level                                      location method  \
# 0  269.58322  paid            Chicago-Naperville-Elgin, IL-IN-WI    PUT
# 1  124.78649  free  Washington-Arlington-Alexandria, DC-VA-MD-WV    PUT
# 2   76.25098  paid                  Lake Havasu City-Kingman, AZ    PUT
# 3  238.36689  paid                   Portland-South Portland, ME    PUT
#
#       ...                 ts  \
# 0     ...      1542837407796
# 1     ...      1542171963796
# 2     ...      1542618860796
# 3     ...      1543358159796
#
#                                            userAgent  userId  \
# ...

# %%
df.withColumn('hour', hour(df.start_time)).withColumn('day', dayofmonth(df.start_time)).withColumn('week', weekofyear(df.start_time)).withColumn('month', month(df.start_time)).withColumn('year', year(df.start_time)).limit(10).toPandas()
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0              Elena  Logged In      Lily      F              5     Koch
# 1          Percubaba  Logged In    Sylvie      F              4     Cruz
# 2  Calvin Richardson  Logged In     Layla      F             98  Griffin
# 3        Samy Deluxe  Logged In     Tegan      F             43   Levine
#
#       length level                                      location method  ...   \
# 0  269.58322  paid            Chicago-Naperville-Elgin, IL-IN-WI    PUT  ...
# 1  124.78649  free  Washington-Arlington-Alexandria, DC-VA-MD-WV    PUT  ...
# 2   76.25098  paid                  Lake Havasu City-Kingman, AZ    PUT  ...
# 3  238.36689  paid                   Portland-South Portland, ME    PUT  ...
#
#             title   duration  year           artist_id  \
# 0  Setanta matins  269.58322  2018  AR5KOSW1187FB35FF4
# 1           Intro   75.67628  2018  AR558FS1187FB45658
# ...

# %%
# %run etl.py
# Out:
# Done
